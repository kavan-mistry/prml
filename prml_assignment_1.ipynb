# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### Exereise 1
#     * Load the data
#     * Read first 5 rows to get headers
#     * Read 2900 rows that contains information on 2007-02-01 and 2007-02-02
#     * converting date and time variables to Date/Time format

# %%
import pandas as pd

# %%
# data loading 

d = pd.read_csv('household_power_consumption.txt', sep=";")
df = pd.DataFrame(d)
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14280\3729238779.py:3: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   d = pd.read_csv('household_power_consumption.txt', sep=";")
#                Date      Time Global_active_power Global_reactive_power  \
# 0        16/12/2006  17:24:00               4.216                 0.418
# 1        16/12/2006  17:25:00               5.360                 0.436
# 2        16/12/2006  17:26:00               5.374                 0.498
# 3        16/12/2006  17:27:00               5.388                 0.502
# 4        16/12/2006  17:28:00               3.666                 0.528
# ...             ...       ...                 ...                   ...
# 2075254  26/11/2010  20:58:00               0.946                   0.0
# 2075255  26/11/2010  20:59:00               0.944                   0.0
# 2075256  26/11/2010  21:00:00               0.938                   0.0
# ...

# %%
# Read first 5 rows to get headers

df.head(5)
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %%
# converting date and time variables to Date/Time format

# df = pd.to_datetime(df['Date'], format = '%d/%m/%Y').dt.date

df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.time

df
# Out:
#               Date      Time Global_active_power Global_reactive_power  \
# 0       2006-12-16  17:24:00               4.216                 0.418
# 1       2006-12-16  17:25:00               5.360                 0.436
# 2       2006-12-16  17:26:00               5.374                 0.498
# 3       2006-12-16  17:27:00               5.388                 0.502
# 4       2006-12-16  17:28:00               3.666                 0.528
# ...            ...       ...                 ...                   ...
# 2075254 2010-11-26  20:58:00               0.946                   0.0
# 2075255 2010-11-26  20:59:00               0.944                   0.0
# 2075256 2010-11-26  21:00:00               0.938                   0.0
# 2075257 2010-11-26  21:01:00               0.934                   0.0
# 2075258 2010-11-26  21:02:00               0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
# Read 2900 rows that contains information on 2007-02-01 and 2007-02-02

df_date = df.loc[(df['Date'] >= '2007-02-01') & (df['Date'] < '2007-02-03')].head(2900)
df_date
# Out:
#             Date      Time Global_active_power Global_reactive_power  Voltage  \
# 66636 2007-02-01  00:00:00               0.326                 0.128  243.150
# 66637 2007-02-01  00:01:00               0.326                 0.130  243.320
# 66638 2007-02-01  00:02:00               0.324                 0.132  243.510
# 66639 2007-02-01  00:03:00               0.324                 0.134  243.900
# 66640 2007-02-01  00:04:00               0.322                 0.130  243.160
# ...          ...       ...                 ...                   ...      ...
# 69511 2007-02-02  23:55:00               3.696                 0.226  240.900
# 69512 2007-02-02  23:56:00               3.698                 0.226  241.020
# 69513 2007-02-02  23:57:00               3.684                 0.224  240.480
# 69514 2007-02-02  23:58:00               3.658                 0.220  239.610
# 69515 2007-02-02  23:59:00               3.680                 0.224  240.370
#
# ...

# %% [markdown]
# ### Exereise 2
#     * Subset the loaded data for 2007-02-01 and 2007-02-02

# %%
subset_df = df.loc[(df['Date'] >= '2007-02-01') & (df['Date'] < '2007-02-03')]

subset_df
# Out:
#             Date      Time Global_active_power Global_reactive_power  Voltage  \
# 66636 2007-02-01  00:00:00               0.326                 0.128  243.150
# 66637 2007-02-01  00:01:00               0.326                 0.130  243.320
# 66638 2007-02-01  00:02:00               0.324                 0.132  243.510
# 66639 2007-02-01  00:03:00               0.324                 0.134  243.900
# 66640 2007-02-01  00:04:00               0.322                 0.130  243.160
# ...          ...       ...                 ...                   ...      ...
# 69511 2007-02-02  23:55:00               3.696                 0.226  240.900
# 69512 2007-02-02  23:56:00               3.698                 0.226  241.020
# 69513 2007-02-02  23:57:00               3.684                 0.224  240.480
# 69514 2007-02-02  23:58:00               3.658                 0.220  239.610
# 69515 2007-02-02  23:59:00               3.680                 0.224  240.370
#
# ...

# %% [markdown]
# ### Exereise 3 : Create plots
#     * Histogram of Global active power consumption
#     * Global active power consumption over time
#     * Energy sub metering

# %%
# Histogram of Global active power consumption

df['Global_active_power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Date'],df['Global_active_power'])
plt.xlabel('Date')
plt.ylabel('Global_active_power')
plt.title('Histogram of Global active power consumption')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
df['Time'] = df['Time'].astype(str)
df
# Out:
#               Date      Time  Global_active_power Global_reactive_power  \
# 0       2006-12-16  17:24:00                4.216                 0.418
# 1       2006-12-16  17:25:00                5.360                 0.436
# 2       2006-12-16  17:26:00                5.374                 0.498
# 3       2006-12-16  17:27:00                5.388                 0.502
# 4       2006-12-16  17:28:00                3.666                 0.528
# ...            ...       ...                  ...                   ...
# 2075254 2010-11-26  20:58:00                0.946                   0.0
# 2075255 2010-11-26  20:59:00                0.944                   0.0
# 2075256 2010-11-26  21:00:00                0.938                   0.0
# 2075257 2010-11-26  21:01:00                0.934                   0.0
# 2075258 2010-11-26  21:02:00                0.932                   0.0
#
#          Voltage Global_intensity Sub_metering_1 Sub_metering_2  \
# ...

# %%
# Global active power consumption over time

plt.plot(df['Time'], df['Global_active_power'])
plt.xlabel('Time')
plt.ylabel('Global_active_power')
plt.title('Global active power consumption over time')
plt.rcParams['figure.figsize'] = [10, 5]
plt.show()

# %%
# Energy sub metering

df['Sub_metering_1'] = pd.to_numeric(df['Sub_metering_1'], errors='coerce')
df['Sub_metering_2'] = pd.to_numeric(df['Sub_metering_2'], errors='coerce')
df['Sub_metering_3'] = pd.to_numeric(df['Sub_metering_3'], errors='coerce')

plt.subplot(3, 1, 1)
plt.plot(df['Date'], df['Sub_metering_1'], label='Sub metering 1')
plt.xlabel('Date')
plt.ylabel('Sub-metering Values 1')

plt.subplot(3, 1, 2)
plt.plot(df['Date'], df['Sub_metering_2'], label='Sub metering 2')
plt.xlabel('Date')
plt.ylabel('Sub-metering Values 2')

plt.subplot(3, 1, 3)
plt.plot(df['Date'], df['Sub_metering_3'], label='Sub metering 3')
plt.xlabel('Date')
plt.ylabel('Sub-metering Values 3')

# plt.rcParams['figure.figsize'] = [20, 10]
plt.show()
